# %% [markdown]
# Practice: get full-width half-max (FWHM) and peak wavelength of a spectrum

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Import function "getFWHM" defined in separate ipynb by using magic command %

# %%
# %run getFWHM.ipynb

# %% [markdown]
# Run script on .csv containing spectrum data
# this plots spectrum, gets the peak wavelength and FWHM

# %%
dn = '/mnt/e/C_2L6IPB6/PycharmProjects/PyPractice/'
getFWHM('cyan_testSpec.csv')
# Out:
# peak wavelength (nm) is:
# 490.0
# FWHM (nm) is:
# 104.0
